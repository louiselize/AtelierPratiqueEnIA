# %%
import requests

url = "https://api.apilayer.com/currency_data/change?start_date=2002-01-01&end_date=2023-02-16"

payload = {}
headers= {
  "apikey": "rIlBJlvsBhBWpKShhOcN035R6WMToEZv"
}

response = requests.request("GET", url, headers=headers, data = payload)

status_code = response.status_code
result = response.text

# %%
result
# Out:
# '{\n    "success": true,\n    "change": true,\n    "start_date": "2002-01-01",\n    "end_date": "2023-02-16",\n    "source": "USD",\n    "quotes": {\n        "USDAED": {\n            "start_rate": 3.67266,\n            "end_rate": 3.67295,\n            "change": 0.0003,\n            "change_pct": 0.0079\n        },\n        "USDAFN": {\n            "start_rate": "unavailable",\n            "end_rate": 89.999861,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDALL": {\n            "start_rate": 137.694315,\n            "end_rate": 108.29885,\n            "change": -29.3955,\n            "change_pct": -21.3484\n        },\n        "USDAMD": {\n            "start_rate": 568.109611,\n            "end_rate": 393.883632,\n            "change": -174.226,\n            "change_pct": -30.6677\n        },\n        "USDANG": {\n            "start_rate": 1.79,\n            "end_rate": 1.802218,\n            "change": 0.0122,\n            "change_pct": 0.6826\n        },\n        "USDAOA": {\n            "start_rate": "unavailable",\n            "end_rate": 507.502481,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDARS": {\n            "start_rate": 1.000337,\n            "end_rate": 192.796899,\n            "change": 191.7966,\n            "change_pct": 19\n        },\n        "USDAUD": {\n            "start_rate": 1.960294,\n            "end_rate": 1.456885,\n            "change": -0.5034,\n            "change_pct": -25.6803\n        },\n        "USDAWG": {\n            "start_rate": 1.79,\n            "end_rate": 1.8,\n            "change": 0.01,\n            "change_pct": 0.5587\n        },\n        "USDAZN": {\n            "start_rate": "unavailable",\n            "end_rate": 1.700423,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDBAM": {\n            "start_rate": "unavailable",\n            "end_rate": 1.826905,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDBBD": {\n            "start_rate": 2,\n            "end_rate": 2.019037,\n            "change": 0.019,\n            "change_pct": 0.9518\n        },\n        "USDBDT": {\n            "start_rate": 57.238284,\n            "end_rate": 105.796071,\n            "change": 48.5578,\n            "change_pct": 84.8345\n        },\n        "USDBGN": {\n            "start_rate": "unavailable",\n            "end_rate": 1.83267,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDBHD": {\n            "start_rate": 0.37643,\n            "end_rate": 0.376962,\n            "change": 0.0005,\n            "change_pct": 0.1413\n        },\n        "USDBIF": {\n            "start_rate": 851.083626,\n            "end_rate": 2070,\n            "change": 1,\n            "change_pct": 143.2193\n        },\n        "USDBMD": {\n            "start_rate": 1,\n            "end_rate": 1,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDBND": {\n            "start_rate": 1.856598,\n            "end_rate": 1.333869,\n            "change": -0.5227,\n            "change_pct": -28.1552\n        },\n        "USDBOB": {\n            "start_rate": 6.813684,\n            "end_rate": 6.909842,\n            "change": 0.0962,\n            "change_pct": 1.4112\n        },\n        "USDBRL": {\n            "start_rate": 2.327096,\n            "end_rate": 5.218299,\n            "change": 2.8912,\n            "change_pct": 124.2408\n        },\n        "USDBSD": {\n            "start_rate": 1,\n            "end_rate": 0.999944,\n            "change": -0.0001,\n            "change_pct": -0.0056\n        },\n        "USDBTC": {\n            "start_rate": "unavailable",\n            "end_rate": 4.2424698e-05,\n            "change": 0,\n            "change_pct": 0\n        },\n        "USDBTN": {\n            "start_rate": 48.485079,\n            "end_rate": 82.648334,\n            "change": 34.1633,\n            "change_pct": 70.4614\n    ...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# atelierIAH23
